# %%
import pandas as pd
import numpy as  np

from TargetEncoderv2 import TargetEncoder
from FeatureSelector import FeatureSelector

from sklearn.metrics import *
from sklearn.model_selection import *

import lightgbm as lgb
import logging

# %%
#Read train and test with features
dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

train = pd.read_csv("../input/train_featureset1_v2.csv", dtype=dtypes, compression='gzip')
test = pd.read_csv("../input/test_featureset1_v2.csv", dtype=dtypes, compression='gzip')

# %%
from sklearn.feature_selection import *
feats = ['app','device','os','channel','ip_hour_day_count','ip_count','app_count',
         'device_count','os_count','channel_count','hourofday_count','ip_app_count',
         'app_device_count','app_os_count','app_channel_count','app_hourofday_count',
         'device_hourofday_count','os_hourofday_count','channel_hourofday_count',
         'channel_os_count','ip_mean','app_mean','device_mean','os_mean','channel_mean',
         'hourofday_mean','ip_app_mean','app_device_mean','app_os_mean','app_channel_mean',
         'app_hourofday_mean','device_hourofday_mean','os_hourofday_mean','channel_hourofday_mean','channel_os_mean']

# %%
for col in feats:
    print("ANOVA F Score of feature {} is {}".format(col, f_classif(train[col].fillna(train[col].mean()).reshape(-1,1), train['is_attributed'])))
    print("Chi Score for feature {} is {}".format(col, chi2(train[col].fillna(train[col].mean()).reshape(-1,1), train['is_attributed'])))
    if ((train[col].mean() - test[col].mean())/train[col].std() >= 0.1):
        print("WARNING - CHECK THIS FEATURE OUT MORE CLOSELY")
    print("Stats for train")
    print(train[col].fillna(train[col].mean()).describe())
    print("Stats for test")
    print(test[col].fillna(train[col].mean()).describe())
# Out:
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# ANOVA F Score of feature app is (array([416.79503491]), array([1.87951837e-92]))
# Chi Score for feature app is (array([7691.23260593]), array([0.]))
# Stats for train
# count    100000.00000
# mean         12.04788
# std          14.94150
# min           1.00000
# 25%           3.00000
# 50%          12.00000
# 75%          15.00000
# max         551.00000
# Name: app, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     1.221480e+01
# std      1.164924e+01
# min      0.000000e+00
# 25%      3.000000e+00
# 50%      1.200000e+01
# 75%      1.800000e+01
# max      5.210000e+02
# Name: app, dtype: float64
# ANOVA F Score of feature device is (array([0.04833755]), array([0.82598218]))
# Chi Score for feature device is (array([149.67133928]), array([2.04549138e-34]))
# Stats for train
# count    100000.000000
# mean         21.771250
# std         259.667767
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max        3867.000000
# Name: device, dtype: float64
# Stats for test
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    1.879047e+07
# mean     1.730513e+00
# std      2.597038e+01
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      3.031000e+03
# Name: device, dtype: float64
# ANOVA F Score of feature os is (array([3.82365233]), array([0.05053675]))
# Chi Score for feature os is (array([524.40885328]), array([4.64884628e-116]))
# Stats for train
# count    100000.000000
# mean         22.818280
# std          55.943136
# min           0.000000
# 25%          13.000000
# 50%          18.000000
# 75%          19.000000
# max         866.000000
# Name: os, dtype: float64
# Stats for test
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    1.879047e+07
# mean     1.873312e+01
# std      1.135059e+01
# min      0.000000e+00
# 25%      1.300000e+01
# 50%      1.800000e+01
# 75%      1.900000e+01
# max      6.040000e+02
# Name: os, dtype: float64
# ANOVA F Score of feature channel is (array([54.50797756]), array([1.5601407e-13]))
# Chi Score for feature channel is (array([3408.98126278]), array([0.]))
# Stats for train
# count    100000.000000
# mean        268.832460
# std         129.724248
# min           3.000000
# 25%         145.000000
# 50%         258.000000
# 75%         379.000000
# max         498.000000
# Name: channel, dtype: float64
# Stats for test
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    1.879047e+07
# mean     2.648059e+02
# std      1.355254e+02
# min      0.000000e+00
# 25%      1.350000e+02
# 50%      2.360000e+02
# 75%      4.010000e+02
# max      4.980000e+02
# Name: channel, dtype: float64
# ANOVA F Score of feature ip_hour_day_count is (array([0.67452452]), array([0.41148054]))
# Chi Score for feature ip_hour_day_count is (array([1.84423201]), array([0.17445574]))
# Stats for train
# count    100000.000000
# mean          1.493280
# std           2.020593
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          28.000000
# Name: ip_hour_day_count, dtype: float64
# Stats for test
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /home/mohsin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    1.879047e+07
# mean     1.133618e+03
# std      4.505620e+03
# min      1.000000e+00
# 25%      6.200000e+01
# 50%      1.310000e+02
# 75%      3.120000e+02
# max      4.023100e+04
# Name: ip_hour_day_count, dtype: float64
# ANOVA F Score of feature ip_count is (array([2.82765282]), array([0.09265681]))
# Chi Score for feature ip_count is (array([651.62248223]), array([9.91411445e-144]))
# Stats for train
# count    100000.000000
# mean         28.337405
# std          80.810724
# min           1.000000
# 25%           2.000000
# 50%           7.000000
# 75%          28.337405
# max         647.000000
# Name: ip_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.316915e+01
# std      9.558080e+01
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      8.000000e+00
# 75%      2.833741e+01
# max      6.690000e+02
# Name: ip_count, dtype: float64
# ANOVA F Score of feature app_count is (array([425.07722911]), array([3.01227795e-94]))
# Chi Score for feature app_count is (array([1449444.59780162]), array([0.]))
# Stats for train
# count    100000.000000
# mean       8918.909593
# std        5526.392219
# min           1.000000
# 25%        2985.000000
# 50%        8530.000000
# 75%       12534.000000
# max       17440.000000
# Name: app_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     8.501698e+03
# std      5.437772e+03
# min      1.000000e+00
# 25%      2.422000e+03
# 50%      8.992000e+03
# 75%      1.173700e+04
# max      1.827900e+04
# Name: app_count, dtype: float64
# ANOVA F Score of feature device_count is (array([323.84792775]), array([2.73578522e-72]))
# Chi Score for feature device_count is (array([1498663.94722491]), array([0.]))
# Stats for train
# count    100000.000000
# mean      84789.666587
# std       19840.516124
# min           1.000000
# 25%       89602.000000
# 50%       89617.000000
# 75%       89629.000000
# max       89676.000000
# Name: device_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     8.785376e+04
# std      2.330254e+04
# min      1.000000e+00
# 25%      9.433800e+04
# 50%      9.433800e+04
# 75%      9.433800e+04
# max      9.433800e+04
# Name: device_count, dtype: float64
# ANOVA F Score of feature os_count is (array([38.14734598]), array([6.58503582e-10]))
# Chi Score for feature os_count is (array([324192.35356271]), array([0.]))
# Stats for train
# count    100000.000000
# mean      10955.767904
# std        9650.977017
# min           1.000000
# 25%        2142.000000
# 50%        4953.000000
# 75%       20216.000000
# max       22751.000000
# Name: os_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     1.136675e+04
# std      1.012525e+04
# min      1.000000e+00
# 25%      2.248000e+03
# 50%      4.830000e+03
# 75%      2.122300e+04
# max      2.387000e+04
# Name: os_count, dtype: float64
# ANOVA F Score of feature channel_count is (array([175.73480538]), array([4.47319785e-40]))
# Chi Score for feature channel_count is (array([312067.26384418]), array([0.]))
# WARNING - CHECK THIS FEATURE OUT MORE CLOSELY
# Stats for train
# count    100000.000000
# mean       2316.667167
# std        2030.047222
# min           1.000000
# 25%         781.000000
# 50%        1447.000000
# 75%        2984.000000
# max        7743.000000
# Name: channel_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     1.749874e+03
# std      1.246815e+03
# min      1.000000e+00
# 25%      7.690000e+02
# 50%      1.426000e+03
# 75%      2.936000e+03
# max      8.114000e+03
# Name: channel_count, dtype: float64
# ANOVA F Score of feature hourofday_count is (array([1.85423347]), array([0.17329489]))
# Chi Score for feature hourofday_count is (array([439.86007162]), array([1.16118131e-97]))
# Stats for train
# count    100000.000000
# mean       4654.391280
# std        1050.771686
# min         655.000000
# 25%        4689.000000
# 50%        4906.000000
# 75%        5242.000000
# max        5781.000000
# Name: hourofday_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     5.512900e+03
# std      3.461298e+02
# min      4.867000e+03
# 25%      5.400000e+03
# 50%      5.561000e+03
# 75%      5.619000e+03
# max      6.039000e+03
# Name: hourofday_count, dtype: float64
# ANOVA F Score of feature ip_app_count is (array([3.55433718e-05]), array([0.99524319]))
# Chi Score for feature ip_app_count is (array([0.00044865]), array([0.98310094]))
# Stats for train
# count    100000.000000
# mean          7.084848
# std           9.456679
# min           1.000000
# 25%           4.000000
# 50%           7.084848
# 75%           7.084848
# max         129.000000
# Name: ip_app_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     7.257406e+00
# std      9.619965e+00
# min      1.000000e+00
# 25%      6.000000e+00
# 50%      7.084848e+00
# 75%      7.084848e+00
# max      1.320000e+02
# Name: ip_app_count, dtype: float64
# ANOVA F Score of feature app_device_count is (array([327.17526545]), array([5.18447842e-73]))
# Chi Score for feature app_device_count is (array([1198939.76759119]), array([0.]))
# Stats for train
# count    100000.000000
# mean       8151.986496
# std        5474.535948
# min           1.000000
# 25%        2240.000000
# 50%        7895.000000
# 75%       11815.000000
# max       16844.000000
# Name: app_device_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     7.699558e+03
# std      5.343878e+03
# min      1.000000e+00
# 25%      1.905000e+03
# 50%      8.280000e+03
# 75%      1.116000e+04
# max      1.765600e+04
# Name: app_device_count, dtype: float64
# ANOVA F Score of feature app_os_count is (array([85.63788697]), array([2.20185247e-20]))
# Chi Score for feature app_os_count is (array([127822.21645897]), array([0.]))
# Stats for train
# count    100000.000000
# mean       1060.312064
# std        1258.550843
# min           1.000000
# 25%         124.000000
# 50%         402.000000
# 75%        1941.000000
# max        4191.000000
# Name: app_os_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     1.001151e+03
# std      1.210816e+03
# min      1.000000e+00
# 25%      1.130000e+02
# 50%      3.850000e+02
# 75%      1.724000e+03
# max      4.377000e+03
# Name: app_os_count, dtype: float64
# ANOVA F Score of feature app_channel_count is (array([91.60056902]), array([1.08358849e-21]))
# Chi Score for feature app_channel_count is (array([223241.59746995]), array([0.]))
# WARNING - CHECK THIS FEATURE OUT MORE CLOSELY
# Stats for train
# count    100000.000000
# mean       1549.076527
# std        1943.889443
# min           1.000000
# 25%         420.000000
# 50%         841.000000
# 75%        1600.000000
# max        7475.000000
# Name: app_channel_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     9.693852e+02
# std      9.628801e+02
# min      1.000000e+00
# 25%      3.820000e+02
# 50%      6.660000e+02
# 75%      1.252000e+03
# max      7.833000e+03
# Name: app_channel_count, dtype: float64
# ANOVA F Score of feature app_hourofday_count is (array([246.70672942]), array([1.58099463e-55]))
# Chi Score for feature app_hourofday_count is (array([56332.39391783]), array([0.]))
# Stats for train
# count    100000.000000
# mean        451.430333
# std         321.452547
# min           1.000000
# 25%         140.000000
# 50%         440.000000
# 75%         648.000000
# max        1208.000000
# Name: app_hourofday_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     4.728916e+02
# std      3.096953e+02
# min      1.000000e+00
# 25%      1.490000e+02
# 50%      4.980000e+02
# 75%      6.840000e+02
# max      1.256000e+03
# Name: app_hourofday_count, dtype: float64
# ANOVA F Score of feature device_hourofday_count is (array([97.69361603]), array([5.00423307e-23]))
# Chi Score for feature device_hourofday_count is (array([43568.4000456]), array([0.]))
# Stats for train
# count    100000.000000
# mean       4165.085549
# std        1363.560916
# min           1.000000
# 25%        4305.000000
# 50%        4646.000000
# 75%        4886.000000
# max        5553.000000
# Name: device_hourofday_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     4.825681e+03
# std      1.304990e+03
# min      1.000000e+00
# 25%      5.124000e+03
# 50%      5.151000e+03
# 75%      5.184000e+03
# max      5.796000e+03
# Name: device_hourofday_count, dtype: float64
# ANOVA F Score of feature os_hourofday_count is (array([29.98260669]), array([4.3698444e-08]))
# Chi Score for feature os_hourofday_count is (array([13836.53672551]), array([0.]))
# Stats for train
# count    100000.000000
# mean        538.321915
# std         498.497475
# min           1.000000
# 25%          87.000000
# 50%         245.000000
# 75%        1079.000000
# max        1398.000000
# Name: os_hourofday_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     6.213384e+02
# std      5.523803e+02
# min      1.000000e+00
# 25%      1.150000e+02
# 50%      2.800000e+02
# 75%      1.180000e+03
# max      1.459000e+03
# Name: os_hourofday_count, dtype: float64
# ANOVA F Score of feature channel_hourofday_count is (array([86.63635126]), array([1.32954006e-20]))
# Chi Score for feature channel_hourofday_count is (array([13054.05388586]), array([0.]))
# WARNING - CHECK THIS FEATURE OUT MORE CLOSELY
# Stats for train
# count    100000.000000
# mean        125.600253
# std         137.627037
# min           1.000000
# 25%          40.000000
# 50%          81.000000
# 75%         156.000000
# max         662.000000
# Name: channel_hourofday_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     9.855884e+01
# std      7.254250e+01
# min      1.000000e+00
# 25%      4.300000e+01
# 50%      7.700000e+01
# 75%      1.380000e+02
# max      6.880000e+02
# Name: channel_hourofday_count, dtype: float64
# ANOVA F Score of feature channel_os_count is (array([44.82555475]), array([2.16525639e-11]))
# Chi Score for feature channel_os_count is (array([24472.47997884]), array([0.]))
# WARNING - CHECK THIS FEATURE OUT MORE CLOSELY
# Stats for train
# count    100000.000000
# mean        274.256524
# std         387.034593
# min           1.000000
# 25%          30.000000
# 50%         113.000000
# 75%         348.000000
# max        1869.000000
# Name: channel_os_count, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     2.030345e+02
# std      2.403389e+02
# min      1.000000e+00
# 25%      2.700000e+01
# 50%      8.700000e+01
# 75%      3.030000e+02
# max      1.943000e+03
# Name: channel_os_count, dtype: float64
# ANOVA F Score of feature ip_mean is (array([0.03422992]), array([0.85321898]))
# Chi Score for feature ip_mean is (array([0.01283494]), array([0.90979952]))
# Stats for train
# count    100000.000000
# mean          0.000932
# std           0.018689
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: ip_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     1.028836e-03
# std      1.911438e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      9.315310e-04
# max      1.000000e+00
# Name: ip_mean, dtype: float64
# ANOVA F Score of feature app_mean is (array([17622.07308939]), array([0.]))
# Chi Score for feature app_mean is (array([2826.92306843]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.002227
# std           0.020497
# min           0.000000
# 25%           0.000000
# 50%           0.000172
# 75%           0.000246
# max           1.000000
# Name: app_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.503121e-03
# std      2.359485e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.188304e-04
# 75%      6.013229e-04
# max      1.000000e+00
# Name: app_mean, dtype: float64
# ANOVA F Score of feature device_mean is (array([1878.94355531]), array([0.]))
# Chi Score for feature device_mean is (array([133.97366528]), array([5.53649995e-31]))
# Stats for train
# count    100000.000000
# mean          0.002184
# std           0.012595
# min           0.000000
# 25%           0.001529
# 50%           0.001540
# 75%           0.001551
# max           1.000000
# Name: device_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.001489e-03
# std      1.525056e-02
# min      0.000000e+00
# 25%      1.547627e-03
# 50%      1.547627e-03
# 75%      1.547627e-03
# max      1.000000e+00
# Name: device_mean, dtype: float64
# ANOVA F Score of feature os_mean is (array([5965.57293985]), array([0.]))
# Chi Score for feature os_mean is (array([364.45592747]), array([3.01533033e-81]))
# Stats for train
# count    100000.000000
# mean          0.002271
# std           0.012125
# min           0.000000
# 25%           0.001003
# 50%           0.001239
# 75%           0.001721
# max           1.000000
# Name: os_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.289641e-03
# std      1.680211e-02
# min      0.000000e+00
# 25%      1.065341e-03
# 50%      1.177967e-03
# 75%      1.717637e-03
# max      1.000000e+00
# Name: os_mean, dtype: float64
# ANOVA F Score of feature channel_mean is (array([16503.60621924]), array([0.]))
# Chi Score for feature channel_mean is (array([2361.86299563]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.002252
# std           0.019378
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000325
# max           1.000000
# Name: channel_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     2.491447e-03
# std      2.063335e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      4.045307e-04
# max      1.000000e+00
# Name: channel_mean, dtype: float64
# ANOVA F Score of feature hourofday_mean is (array([0.01789815]), array([0.89357367]))
# Chi Score for feature hourofday_mean is (array([4.62233168e-06]), array([0.99828458]))
# Stats for train
# count    100000.000000
# mean          0.002269
# std           0.000765
# min           0.000000
# 25%           0.001863
# 50%           0.002420
# 75%           0.002872
# max           0.003713
# Name: hourofday_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     2.361910e-03
# std      5.662409e-04
# min      1.655903e-03
# 25%      1.779676e-03
# 50%      2.054654e-03
# 75%      2.903284e-03
# max      3.057004e-03
# Name: hourofday_mean, dtype: float64
# ANOVA F Score of feature ip_app_mean is (array([9.73488718]), array([0.00180855]))
# Chi Score for feature ip_app_mean is (array([2.15874694]), array([0.14176025]))
# Stats for train
# count    100000.000000
# mean          0.000271
# std           0.007751
# min           0.000000
# 25%           0.000000
# 50%           0.000271
# 75%           0.000271
# max           1.000000
# Name: ip_app_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     4.250320e-04
# std      1.068986e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.709320e-04
# 75%      2.709320e-04
# max      1.000000e+00
# Name: ip_app_mean, dtype: float64
# ANOVA F Score of feature app_device_mean is (array([14765.94809714]), array([0.]))
# Chi Score for feature app_device_mean is (array([2942.90649334]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.002117
# std           0.022007
# min           0.000000
# 25%           0.000000
# 50%           0.000085
# 75%           0.000255
# max           1.000000
# Name: app_device_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.100056e-03
# std      2.342955e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.034064e-05
# 75%      6.369427e-04
# max      1.000000e+00
# Name: app_device_mean, dtype: float64
# ANOVA F Score of feature app_os_mean is (array([16569.76029284]), array([0.]))
# Chi Score for feature app_os_mean is (array([4766.72704905]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.001974
# std           0.025728
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: app_os_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.254976e-03
# std      2.879276e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: app_os_mean, dtype: float64
# ANOVA F Score of feature app_channel_mean is (array([27406.044919]), array([0.]))
# Chi Score for feature app_channel_mean is (array([6477.09946008]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.002187
# std           0.025664
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000135
# max           1.000000
# Name: app_channel_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.015899e-03
# std      2.842992e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: app_channel_mean, dtype: float64
# ANOVA F Score of feature app_hourofday_mean is (array([6254.68908044]), array([0.]))
# Chi Score for feature app_hourofday_mean is (array([1588.97187615]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.002009
# std           0.023290
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: app_hourofday_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.345597e-03
# std      2.567090e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: app_hourofday_mean, dtype: float64
# ANOVA F Score of feature device_hourofday_mean is (array([2536.05503698]), array([0.]))
# Chi Score for feature device_hourofday_mean is (array([150.46280995]), array([1.37341408e-34]))
# Stats for train
# count    100000.000000
# mean          0.002064
# std           0.011204
# min           0.000000
# 25%           0.001033
# 50%           0.001513
# 75%           0.001954
# max           1.000000
# Name: device_hourofday_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     2.913513e-03
# std      1.601988e-02
# min      0.000000e+00
# 25%      8.770007e-04
# 50%      1.366120e-03
# 75%      1.929012e-03
# max      1.000000e+00
# Name: device_hourofday_mean, dtype: float64
# ANOVA F Score of feature os_hourofday_mean is (array([3032.89981233]), array([0.]))
# Chi Score for feature os_hourofday_mean is (array([411.27733697]), array([1.9323423e-91]))
# Stats for train
# count    100000.000000
# mean          0.002241
# std           0.017696
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.001744
# max           1.000000
# Name: os_hourofday_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     3.044722e-03
# std      2.220251e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.543210e-03
# max      1.000000e+00
# Name: os_hourofday_mean, dtype: float64
# ANOVA F Score of feature channel_hourofday_mean is (array([6346.80783237]), array([0.]))
# Chi Score for feature channel_hourofday_mean is (array([1441.46851488]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.002085
# std           0.022443
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: channel_hourofday_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     2.258014e-03
# std      2.124314e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: channel_hourofday_mean, dtype: float64
# ANOVA F Score of feature channel_os_mean is (array([13950.39067722]), array([0.]))
# Chi Score for feature channel_os_mean is (array([3472.0218777]), array([0.]))
# Stats for train
# count    100000.000000
# mean          0.001999
# std           0.023808
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: channel_os_mean, dtype: float64
# Stats for test
# count    1.879047e+07
# mean     2.686341e-03
# std      2.751781e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: channel_os_mean, dtype: float64

# %%
#remove 
#ip_app_count
#ip_mean
#hourofday_mean
#ip_app_mean
