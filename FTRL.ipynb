# %%
## The below code is based on https://www.kaggle.com/titericz/giba-darragh-ftrl-rerevisited/code

# %%
"""
Thanks to tinrtgu for the wonderful base script
Use pypy for faster computations.!

... further ripped from SRK -- https://www.kaggle.com/sudalairajkumar/ftrl-starter-with-leakage-vars

any ideas on how to use cython to further speed it up, would love to see it
"""
import csv
import time
from csv import DictReader
from math import exp, log, sqrt
from numba import jit

# %%
##############################################################################
# parameters #################################################################
##############################################################################

# A, paths
data_path = "../input/"
train = data_path+'train.csv'               # path to training file
test = data_path+'test.csv'                 # path to testing file
submission = 'sub_proba.csv'  # path of to be outputted submission file

# B, model
alpha = .055  # learning rate
beta = 0.   # smoothing parameter for adaptive learning rate
L1 = 0.    # L1 regularization, larger value means more regularized
L2 = 0.     # L2 regularization, larger value means more regularized

# C, feature/hash trick
D = 2 ** 26             # number of weights to use
interaction = False     # whether to enable poly2 feature interactions

# D, training/validation
epoch = 3      # learn training data for N passes
holdday = ''   # data after date N (exclusive) are used as validation

# %%
##############################################################################
# class, function, generator definitions #####################################
##############################################################################

class ftrl_proximal(object):
    ''' Our main algorithm: Follow the regularized leader - proximal

        In short,
        this is an adaptive-learning-rate sparse logistic-regression with
        efficient L1-L2-regularization

        Reference:
        http://www.eecs.tufts.edu/~dsculley/papers/ad-click-prediction.pdf
    '''

    def __init__(self, alpha, beta, L1, L2, D, interaction):
        # parameters
        self.alpha = alpha
        self.beta = beta
        self.L1 = L1
        self.L2 = L2

        # feature related parameters
        self.D = D
        self.interaction = interaction

        # model
        # n: squared sum of past gradients
        # z: weights
        # w: lazy weights
        self.n = [0.] * D
        self.z = [0.] * D
        self.w = {}

    def _indices(self, x):
        ''' A helper generator that yields the indices in x

            The purpose of this generator is to make the following
            code a bit cleaner when doing feature interaction.
        '''

        # first yield index of the bias term
        yield 0

        # then yield the normal indices
        for index in x:
            yield index
        '''
        # now yield interactions (if applicable)
        if self.interaction:
            D = self.D
            L = len(x)

            x = sorted(x)
            for i in xrange(L):
                for j in xrange(i+1, L):
                    # one-hot encode interactions with hash trick
                    yield abs(hash(str(x[i]) + '_' + str(x[j]))) % D
        '''

    def predict(self, x):
        ''' Get probability estimation on x

            INPUT:
                x: features

            OUTPUT:
                probability of p(y = 1 | x; w)
        '''

        # parameters
        alpha = self.alpha
        beta = self.beta
        L1 = self.L1
        L2 = self.L2

        # model
        n = self.n
        z = self.z
        w = {}

        # wTx is the inner product of w and x
        wTx = 0.
        for i in self._indices(x):
            sign = -1. if z[i] < 0 else 1.  # get sign of z[i]

            # build w on the fly using z and n, hence the name - lazy weights
            # we are doing this at prediction instead of update time is because
            # this allows us for not storing the complete w
            if sign * z[i] <= L1:
                # w[i] vanishes due to L1 regularization
                w[i] = 0.
            else:
                # apply prediction time L1, L2 regularization to z and get w
                w[i] = (sign * L1 - z[i]) / ((beta + sqrt(n[i])) / alpha + L2)

            wTx += w[i]

        # cache the current w for update stage
        self.w = w

        # bounded sigmoid function, this is the probability estimation
        return 1. / (1. + exp(-max(min(wTx, 35.), -35.)))

    def update(self, x, p, y):
        ''' Update model using x, p, y

            INPUT:
                x: feature, a list of indices
                p: click probability prediction of our model
                y: answer

            MODIFIES:
                self.n: increase by squared gradient
                self.z: weights
        '''

        # parameter
        alpha = self.alpha

        # model
        n = self.n
        z = self.z
        w = self.w

        # gradient under logloss
        g = p - y

        # update z and n
        for i in self._indices(x):
            sigma = (sqrt(n[i] + g * g) - sqrt(n[i])) / alpha
            z[i] += g - sigma * w[i]
            n[i] += g * g

# %%
@jit
def logloss(p, y):
    ''' FUNCTION: Bounded logloss

        INPUT:
            p: our prediction
            y: real answer

        OUTPUT:
            logarithmic loss of p given y
    '''

    p = max(min(p, 1. - 10e-15), 10e-15)
    return -log(p) if y == 1. else -log(1. - p)


def data(path, D):
    ''' GENERATOR: Apply hash-trick to the original csv row
                   and for simplicity, we one-hot-encode everything

        INPUT:
            path: path to training or testing file
            D: the max index that we can hash to

        YIELDS:
            ID: id of the instance, mainly useless
            x: a list of hashed and one-hot-encoded 'indices'
               we only need the index since all values are either 0 or 1
            y: y = 1 if we have a click, else we have y = 0
    '''
    for t, row in enumerate(DictReader(open(path))):
        
        # process clicks
        y = 0.
        if 'is_attributed' in row:
            if row['is_attributed'] == '1':
                y = 1.
            del row['is_attributed'], row['attributed_time']
        
        try:
            click_id = row['click_id']
        except:
            click_id = ''
            
        # process id
        x = []
        
        # Parse hour and date
        date, time = row['click_time'].split(' ')
        hour = time.split(':')[0]
        row['hour'] = hour
        x.append(abs(hash('hour_%s'%(hour))) % D)
        del row['click_time']
        
        # Add the rest of the features
        for k, v in row.items():
            x.append(abs(hash('%s_%s'%(k, v))) % D)
        
        # Add an interaction
        x.append(abs(hash('%s_app_chl_%s'%(row['channel'], row['app']))) % D)
        x.append(abs(hash('%s_os__chl_%s'%(row['channel'], row['os']))) % D)
        x.append(abs(hash('%s_device__chl_%s'%(row['channel'], row['device']))) % D)
        x.append(abs(hash('%s_os__device_%s'%(row['device'], row['os']))) % D)
        x.append(abs(hash('%s_device__app_%s'%(row['device'], row['app']))) % D)
        x.append(abs(hash('%s_os__app_%s'%(row['app'], row['os']))) % D)
        x.append(abs(hash('%s_hr__chl_%s'%(row['channel'], row['hour']))) % D)
        x.append(abs(hash('%s_hr__device_%s'%(row['device'], row['hour']))) % D)
        x.append(abs(hash('%s_hr__app_%s'%(row['app'], row['hour']))) % D)
        x.append(abs(hash('%s_os__hr_%s'%(row['os'], row['hour']))) % D)
        
        yield t, x, y, date, click_id

# %%
##############################################################################
# start training #############################################################
##############################################################################

start_time = time.time()

# initialize ourselves a learner
learner = ftrl_proximal(alpha, beta, L1, L2, D, interaction)

# start training
for e in range(epoch):
    loss = 0.
    count = 0.000001
    date = 0

    for t, x, y, date, _ in data(train, D):  # data is a generator
        #    t: just a instance counter
        # date: you know what this is
        #   ID: id provided in original data
        #    x: features
        #    y: label (click)

        # step 1, get prediction from learner
        p = learner.predict(x)

        if (holdday and date == holdday):
            # step 2-1, calculate validation loss
            #           we do not train with the validation data so that our
            #           validation loss is an accurate estimation
            #
            # holdafter: train instances from day 1 to day N
            #            validate with instances from day N + 1 and after
            #
            # holdout: validate with every N instance, train with others
            loss += logloss(p, y)
            count += 1.0
        else:
            # step 2-2, update learner with label (click) information
            learner.update(x, p, y)

        if t%1000000 == 0:
            print("Train Processed Rows : %sM ; %.5f ;%ss "%( int(t/1e+6), loss/count, '%0.0f'%(time.time()-start_time)))
# Out:
# Train Processed Rows : 0M ; 0.00000 ;6s
# Train Processed Rows : 1M ; 0.00000 ;55s
# Train Processed Rows : 2M ; 0.00000 ;103s
# Train Processed Rows : 3M ; 0.00000 ;151s
# Train Processed Rows : 4M ; 0.00000 ;199s
# Train Processed Rows : 5M ; 0.00000 ;247s
# Train Processed Rows : 6M ; 0.00000 ;296s
# Train Processed Rows : 7M ; 0.00000 ;344s
# Train Processed Rows : 8M ; 0.00000 ;395s
# Train Processed Rows : 9M ; 0.00000 ;449s
# Train Processed Rows : 10M ; 0.00000 ;513s
# Train Processed Rows : 11M ; 0.00000 ;584s
# Train Processed Rows : 12M ; 0.00000 ;656s
# Train Processed Rows : 13M ; 0.00000 ;734s
# Train Processed Rows : 14M ; 0.00000 ;811s
# Train Processed Rows : 15M ; 0.00000 ;863s
# Train Processed Rows : 16M ; 0.00000 ;914s
# Train Processed Rows : 17M ; 0.00000 ;966s
# Train Processed Rows : 18M ; 0.00000 ;1017s
# Train Processed Rows : 19M ; 0.00000 ;1073s
# Train Processed Rows : 20M ; 0.00000 ;1125s
# Train Processed Rows : 21M ; 0.00000 ;1174s
# Train Processed Rows : 22M ; 0.00000 ;1228s
# Train Processed Rows : 23M ; 0.00000 ;1288s
# Train Processed Rows : 24M ; 0.00000 ;1352s
# Train Processed Rows : 25M ; 0.00000 ;1414s
# Train Processed Rows : 26M ; 0.00000 ;1472s
# Train Processed Rows : 27M ; 0.00000 ;1538s
# Train Processed Rows : 28M ; 0.00000 ;1611s
# Train Processed Rows : 29M ; 0.00000 ;1674s
# Train Processed Rows : 30M ; 0.00000 ;1733s
# Train Processed Rows : 31M ; 0.00000 ;1805s
# Train Processed Rows : 32M ; 0.00000 ;1867s
# Train Processed Rows : 33M ; 0.00000 ;1924s
# Train Processed Rows : 34M ; 0.00000 ;1995s
# Train Processed Rows : 35M ; 0.00000 ;2063s
# Train Processed Rows : 36M ; 0.00000 ;2120s
# Train Processed Rows : 37M ; 0.00000 ;2177s
# Train Processed Rows : 38M ; 0.00000 ;2233s
# Train Processed Rows : 39M ; 0.00000 ;2293s
# Train Processed Rows : 40M ; 0.00000 ;2350s
# Train Processed Rows : 41M ; 0.00000 ;2407s
# Train Processed Rows : 42M ; 0.00000 ;2467s
# Train Processed Rows : 43M ; 0.00000 ;2528s
# Train Processed Rows : 44M ; 0.00000 ;2626s
# Train Processed Rows : 45M ; 0.00000 ;2698s
# Train Processed Rows : 46M ; 0.00000 ;2767s
# Train Processed Rows : 47M ; 0.00000 ;2839s
# Train Processed Rows : 48M ; 0.00000 ;2923s
# Train Processed Rows : 49M ; 0.00000 ;2988s
# Train Processed Rows : 50M ; 0.00000 ;3043s
# Train Processed Rows : 51M ; 0.00000 ;3103s
# Train Processed Rows : 52M ; 0.00000 ;3157s
# Train Processed Rows : 53M ; 0.00000 ;3211s
# Train Processed Rows : 54M ; 0.00000 ;3269s
# Train Processed Rows : 55M ; 0.00000 ;3329s
# Train Processed Rows : 56M ; 0.00000 ;3388s
# Train Processed Rows : 57M ; 0.00000 ;3446s
# Train Processed Rows : 58M ; 0.00000 ;3503s
# Train Processed Rows : 59M ; 0.00000 ;3560s
# Train Processed Rows : 60M ; 0.00000 ;3618s
# Train Processed Rows : 61M ; 0.00000 ;3677s
# Train Processed Rows : 62M ; 0.00000 ;3732s
# Train Processed Rows : 63M ; 0.00000 ;3790s
# Train Processed Rows : 64M ; 0.00000 ;3847s
# Train Processed Rows : 65M ; 0.00000 ;3912s
# Train Processed Rows : 66M ; 0.00000 ;3978s
# Train Processed Rows : 67M ; 0.00000 ;4041s
# Train Processed Rows : 68M ; 0.00000 ;4099s
# Train Processed Rows : 69M ; 0.00000 ;4156s
# Train Processed Rows : 70M ; 0.00000 ;4222s
# Train Processed Rows : 71M ; 0.00000 ;4277s
# Train Processed Rows : 72M ; 0.00000 ;4330s
# Train Processed Rows : 73M ; 0.00000 ;4384s
# Train Processed Rows : 74M ; 0.00000 ;4442s
# Train Processed Rows : 75M ; 0.00000 ;4501s
# Train Processed Rows : 76M ; 0.00000 ;4559s
# Train Processed Rows : 77M ; 0.00000 ;4615s
# Train Processed Rows : 78M ; 0.00000 ;4668s
# Train Processed Rows : 79M ; 0.00000 ;4720s
# Train Processed Rows : 80M ; 0.00000 ;4775s
# Train Processed Rows : 81M ; 0.00000 ;4829s
# Train Processed Rows : 82M ; 0.00000 ;4881s
# Train Processed Rows : 83M ; 0.00000 ;4933s
# Train Processed Rows : 84M ; 0.00000 ;4984s
# Train Processed Rows : 85M ; 0.00000 ;5034s
# Train Processed Rows : 86M ; 0.00000 ;5084s
# Train Processed Rows : 87M ; 0.00000 ;5139s
# Train Processed Rows : 88M ; 0.00000 ;5188s
# Train Processed Rows : 89M ; 0.00000 ;5237s
# Train Processed Rows : 90M ; 0.00000 ;5285s
# Train Processed Rows : 91M ; 0.00000 ;5335s
# Train Processed Rows : 92M ; 0.00000 ;5383s
# Train Processed Rows : 93M ; 0.00000 ;5431s
# Train Processed Rows : 94M ; 0.00000 ;5478s
# Train Processed Rows : 95M ; 0.00000 ;5525s
# Train Processed Rows : 96M ; 0.00000 ;5572s
# Train Processed Rows : 97M ; 0.00000 ;5620s
# Train Processed Rows : 98M ; 0.00000 ;5668s
# Train Processed Rows : 99M ; 0.00000 ;5715s
# Train Processed Rows : 100M ; 0.00000 ;5762s
# Train Processed Rows : 101M ; 0.00000 ;5809s
# Train Processed Rows : 102M ; 0.00000 ;5856s
# Train Processed Rows : 103M ; 0.00000 ;5904s
# Train Processed Rows : 104M ; 0.00000 ;5951s
# Train Processed Rows : 105M ; 0.00000 ;5998s
# Train Processed Rows : 106M ; 0.00000 ;6045s
# Train Processed Rows : 107M ; 0.00000 ;6092s
# Train Processed Rows : 108M ; 0.00000 ;6141s
# Train Processed Rows : 109M ; 0.00000 ;6190s
# Train Processed Rows : 110M ; 0.00000 ;6238s
# Train Processed Rows : 111M ; 0.00000 ;6285s
# Train Processed Rows : 112M ; 0.00000 ;6332s
# Train Processed Rows : 113M ; 0.00000 ;6379s
# Train Processed Rows : 114M ; 0.00000 ;6426s
# Train Processed Rows : 115M ; 0.00000 ;6473s
# Train Processed Rows : 116M ; 0.00000 ;6520s
# Train Processed Rows : 117M ; 0.00000 ;6566s
# Train Processed Rows : 118M ; 0.00000 ;6614s
# Train Processed Rows : 119M ; 0.00000 ;6662s
# Train Processed Rows : 120M ; 0.00000 ;6708s
# Train Processed Rows : 121M ; 0.00000 ;6755s
# Train Processed Rows : 122M ; 0.00000 ;6801s
# Train Processed Rows : 123M ; 0.00000 ;6850s
# Train Processed Rows : 124M ; 0.00000 ;6897s
# Train Processed Rows : 125M ; 0.00000 ;6946s
# Train Processed Rows : 126M ; 0.00000 ;6993s
# Train Processed Rows : 127M ; 0.00000 ;7040s
# Train Processed Rows : 128M ; 0.00000 ;7087s
# Train Processed Rows : 129M ; 0.00000 ;7134s
# Train Processed Rows : 130M ; 0.00000 ;7433s
# Train Processed Rows : 131M ; 0.00000 ;7481s
# Train Processed Rows : 132M ; 0.00000 ;7529s
# Train Processed Rows : 133M ; 0.00000 ;7577s
# Train Processed Rows : 134M ; 0.00000 ;7706s
# Train Processed Rows : 135M ; 0.00000 ;7754s
# Train Processed Rows : 136M ; 0.00000 ;7801s
# Train Processed Rows : 137M ; 0.00000 ;7850s
# Train Processed Rows : 138M ; 0.00000 ;7898s
# Train Processed Rows : 139M ; 0.00000 ;7945s
# Train Processed Rows : 140M ; 0.00000 ;7992s
# Train Processed Rows : 141M ; 0.00000 ;8039s
# Train Processed Rows : 142M ; 0.00000 ;8086s
# Train Processed Rows : 143M ; 0.00000 ;8133s
# Train Processed Rows : 144M ; 0.00000 ;8180s
# Train Processed Rows : 145M ; 0.00000 ;8228s
# Train Processed Rows : 146M ; 0.00000 ;8275s
# Train Processed Rows : 147M ; 0.00000 ;8322s
# Train Processed Rows : 148M ; 0.00000 ;8370s
# Train Processed Rows : 149M ; 0.00000 ;8417s
# Train Processed Rows : 150M ; 0.00000 ;8464s
# Train Processed Rows : 151M ; 0.00000 ;8514s
# Train Processed Rows : 152M ; 0.00000 ;8561s
# Train Processed Rows : 153M ; 0.00000 ;8607s
# Train Processed Rows : 154M ; 0.00000 ;8654s
# Train Processed Rows : 155M ; 0.00000 ;8701s
# Train Processed Rows : 156M ; 0.00000 ;8748s
# Train Processed Rows : 157M ; 0.00000 ;8795s
# Train Processed Rows : 158M ; 0.00000 ;8842s
# Train Processed Rows : 159M ; 0.00000 ;8889s
# Train Processed Rows : 160M ; 0.00000 ;8936s
# Train Processed Rows : 161M ; 0.00000 ;8983s
# Train Processed Rows : 162M ; 0.00000 ;9030s
# Train Processed Rows : 163M ; 0.00000 ;9077s
# Train Processed Rows : 164M ; 0.00000 ;9124s
# Train Processed Rows : 165M ; 0.00000 ;9171s
# Train Processed Rows : 166M ; 0.00000 ;9217s
# Train Processed Rows : 167M ; 0.00000 ;9264s
# Train Processed Rows : 168M ; 0.00000 ;9311s
# Train Processed Rows : 169M ; 0.00000 ;9357s
# Train Processed Rows : 170M ; 0.00000 ;9405s
# Train Processed Rows : 171M ; 0.00000 ;9454s
# Train Processed Rows : 172M ; 0.00000 ;9500s
# Train Processed Rows : 173M ; 0.00000 ;9547s
# Train Processed Rows : 174M ; 0.00000 ;9594s
# Train Processed Rows : 175M ; 0.00000 ;9641s
# Train Processed Rows : 176M ; 0.00000 ;9688s
# Train Processed Rows : 177M ; 0.00000 ;9735s
# Train Processed Rows : 178M ; 0.00000 ;9781s
# Train Processed Rows : 179M ; 0.00000 ;9828s
# Train Processed Rows : 180M ; 0.00000 ;9875s
# Train Processed Rows : 181M ; 0.00000 ;9921s
# Train Processed Rows : 182M ; 0.00000 ;9968s
# Train Processed Rows : 183M ; 0.00000 ;10016s
# Train Processed Rows : 184M ; 0.00000 ;10063s
# Train Processed Rows : 0M ; 0.00000 ;10105s
# Train Processed Rows : 1M ; 0.00000 ;10152s
# Train Processed Rows : 2M ; 0.00000 ;10200s
# Train Processed Rows : 3M ; 0.00000 ;10249s
# Train Processed Rows : 4M ; 0.00000 ;10297s
# Train Processed Rows : 5M ; 0.00000 ;10343s
# Train Processed Rows : 6M ; 0.00000 ;10390s
# Train Processed Rows : 7M ; 0.00000 ;10437s
# Train Processed Rows : 8M ; 0.00000 ;10485s
# Train Processed Rows : 9M ; 0.00000 ;10532s
# Train Processed Rows : 10M ; 0.00000 ;10579s
# Train Processed Rows : 11M ; 0.00000 ;10625s
# Train Processed Rows : 12M ; 0.00000 ;10672s
# Train Processed Rows : 13M ; 0.00000 ;10718s
# Train Processed Rows : 14M ; 0.00000 ;10765s
# Train Processed Rows : 15M ; 0.00000 ;10814s
# Train Processed Rows : 16M ; 0.00000 ;10862s
# Train Processed Rows : 17M ; 0.00000 ;10909s
# Train Processed Rows : 18M ; 0.00000 ;10955s
# Train Processed Rows : 19M ; 0.00000 ;11002s
# Train Processed Rows : 20M ; 0.00000 ;11050s
# Train Processed Rows : 21M ; 0.00000 ;11099s
# Train Processed Rows : 22M ; 0.00000 ;11154s
# Train Processed Rows : 23M ; 0.00000 ;11205s
# Train Processed Rows : 24M ; 0.00000 ;11254s
# Train Processed Rows : 25M ; 0.00000 ;11303s
# Train Processed Rows : 26M ; 0.00000 ;11351s
# Train Processed Rows : 27M ; 0.00000 ;11399s
# Train Processed Rows : 28M ; 0.00000 ;11449s
# Train Processed Rows : 29M ; 0.00000 ;11496s
# Train Processed Rows : 30M ; 0.00000 ;11544s
# Train Processed Rows : 31M ; 0.00000 ;11594s
# Train Processed Rows : 32M ; 0.00000 ;11643s
# Train Processed Rows : 33M ; 0.00000 ;11691s
# Train Processed Rows : 34M ; 0.00000 ;11738s
# Train Processed Rows : 35M ; 0.00000 ;11785s
# Train Processed Rows : 36M ; 0.00000 ;11833s
# Train Processed Rows : 37M ; 0.00000 ;11880s
# Train Processed Rows : 38M ; 0.00000 ;11927s
# Train Processed Rows : 39M ; 0.00000 ;11974s
# Train Processed Rows : 40M ; 0.00000 ;12021s
# Train Processed Rows : 41M ; 0.00000 ;12069s
# Train Processed Rows : 42M ; 0.00000 ;12116s
# Train Processed Rows : 43M ; 0.00000 ;12162s
# Train Processed Rows : 44M ; 0.00000 ;12209s
# Train Processed Rows : 45M ; 0.00000 ;12256s
# Train Processed Rows : 46M ; 0.00000 ;12303s
# Train Processed Rows : 47M ; 0.00000 ;12358s
# Train Processed Rows : 48M ; 0.00000 ;12410s
# Train Processed Rows : 49M ; 0.00000 ;12459s
# Train Processed Rows : 50M ; 0.00000 ;12514s
# Train Processed Rows : 51M ; 0.00000 ;12569s
# Train Processed Rows : 52M ; 0.00000 ;12622s
# Train Processed Rows : 53M ; 0.00000 ;12678s
# Train Processed Rows : 54M ; 0.00000 ;12729s
# Train Processed Rows : 55M ; 0.00000 ;12777s
# Train Processed Rows : 56M ; 0.00000 ;12826s
# Train Processed Rows : 57M ; 0.00000 ;12874s
# Train Processed Rows : 58M ; 0.00000 ;12926s
# Train Processed Rows : 59M ; 0.00000 ;12975s
# Train Processed Rows : 60M ; 0.00000 ;13027s
# Train Processed Rows : 61M ; 0.00000 ;13081s
# Train Processed Rows : 62M ; 0.00000 ;13132s
# Train Processed Rows : 63M ; 0.00000 ;13188s
# Train Processed Rows : 64M ; 0.00000 ;13242s
# Train Processed Rows : 65M ; 0.00000 ;13292s
# Train Processed Rows : 66M ; 0.00000 ;13346s
# Train Processed Rows : 67M ; 0.00000 ;13402s
# Train Processed Rows : 68M ; 0.00000 ;13458s
# Train Processed Rows : 69M ; 0.00000 ;13514s
# Train Processed Rows : 70M ; 0.00000 ;13568s
# Train Processed Rows : 71M ; 0.00000 ;13622s
# Train Processed Rows : 72M ; 0.00000 ;13671s
# Train Processed Rows : 73M ; 0.00000 ;13723s
# Train Processed Rows : 74M ; 0.00000 ;13776s
# Train Processed Rows : 75M ; 0.00000 ;13825s
# Train Processed Rows : 76M ; 0.00000 ;13875s
# Train Processed Rows : 77M ; 0.00000 ;13924s
# Train Processed Rows : 78M ; 0.00000 ;13974s
# Train Processed Rows : 79M ; 0.00000 ;14026s
# Train Processed Rows : 80M ; 0.00000 ;14082s
# Train Processed Rows : 81M ; 0.00000 ;14134s
# Train Processed Rows : 82M ; 0.00000 ;14185s
# Train Processed Rows : 83M ; 0.00000 ;14236s
# Train Processed Rows : 84M ; 0.00000 ;14288s
# Train Processed Rows : 85M ; 0.00000 ;14340s
# Train Processed Rows : 86M ; 0.00000 ;14395s
# Train Processed Rows : 87M ; 0.00000 ;14450s
# Train Processed Rows : 88M ; 0.00000 ;14502s
# Train Processed Rows : 89M ; 0.00000 ;14553s
# Train Processed Rows : 90M ; 0.00000 ;14607s
# Train Processed Rows : 91M ; 0.00000 ;19797s
# Train Processed Rows : 92M ; 0.00000 ;20379s
# Train Processed Rows : 93M ; 0.00000 ;20431s
# Train Processed Rows : 94M ; 0.00000 ;20478s
# Train Processed Rows : 95M ; 0.00000 ;20527s
# Train Processed Rows : 96M ; 0.00000 ;20575s
# Train Processed Rows : 97M ; 0.00000 ;20622s
# Train Processed Rows : 98M ; 0.00000 ;20669s
# Train Processed Rows : 99M ; 0.00000 ;20718s
# Train Processed Rows : 100M ; 0.00000 ;20765s
# Train Processed Rows : 101M ; 0.00000 ;20815s
# Train Processed Rows : 102M ; 0.00000 ;20863s
# Train Processed Rows : 103M ; 0.00000 ;20912s
# Train Processed Rows : 104M ; 0.00000 ;20964s
# Train Processed Rows : 105M ; 0.00000 ;21014s
# Train Processed Rows : 106M ; 0.00000 ;21070s
# Train Processed Rows : 107M ; 0.00000 ;21121s
# Train Processed Rows : 108M ; 0.00000 ;21176s
# Train Processed Rows : 109M ; 0.00000 ;21229s
# Train Processed Rows : 110M ; 0.00000 ;21281s
# Train Processed Rows : 111M ; 0.00000 ;21335s
# Train Processed Rows : 112M ; 0.00000 ;21389s
# Train Processed Rows : 113M ; 0.00000 ;21443s
# Train Processed Rows : 114M ; 0.00000 ;21498s
# Train Processed Rows : 115M ; 0.00000 ;21556s
# Train Processed Rows : 116M ; 0.00000 ;21612s
# Train Processed Rows : 117M ; 0.00000 ;21670s
# Train Processed Rows : 118M ; 0.00000 ;21727s
# Train Processed Rows : 119M ; 0.00000 ;21785s
# Train Processed Rows : 120M ; 0.00000 ;21846s
# Train Processed Rows : 121M ; 0.00000 ;21918s
# Train Processed Rows : 122M ; 0.00000 ;21977s
# Train Processed Rows : 123M ; 0.00000 ;22039s
# Train Processed Rows : 124M ; 0.00000 ;22102s
# Train Processed Rows : 125M ; 0.00000 ;22158s
# Train Processed Rows : 126M ; 0.00000 ;22212s
# Train Processed Rows : 127M ; 0.00000 ;22270s
# Train Processed Rows : 128M ; 0.00000 ;22331s
# Train Processed Rows : 129M ; 0.00000 ;22394s
# Train Processed Rows : 130M ; 0.00000 ;22455s
# Train Processed Rows : 131M ; 0.00000 ;22510s
# Train Processed Rows : 132M ; 0.00000 ;22563s
# Train Processed Rows : 133M ; 0.00000 ;22616s
# Train Processed Rows : 134M ; 0.00000 ;22669s
# Train Processed Rows : 135M ; 0.00000 ;22722s
# Train Processed Rows : 136M ; 0.00000 ;22775s
# Train Processed Rows : 137M ; 0.00000 ;22827s
# Train Processed Rows : 138M ; 0.00000 ;23375s
# Train Processed Rows : 139M ; 0.00000 ;25554s
# Train Processed Rows : 140M ; 0.00000 ;25709s
# Train Processed Rows : 141M ; 0.00000 ;26768s
# Train Processed Rows : 142M ; 0.00000 ;28778s
# Train Processed Rows : 143M ; 0.00000 ;28874s
# Train Processed Rows : 144M ; 0.00000 ;28950s
# Train Processed Rows : 145M ; 0.00000 ;31780s

# %%
##############################################################################
# start testing, and build Kaggle's submission file ##########################
##############################################################################


start_time = time.time()

with open(submission, 'w') as outfile:
    outfile.write('click_id,is_attributed\n')
    for t, x, y, date, click_id in data(test, D):
        p = learner.predict(x)
        outfile.write('%s,%s\n' % (click_id, str(p)))
        if t%1000000 == 0:
            print("Test Processed Rows : %sM ; %ss "%( int(t/1e+6), '%0.0f'%(time.time()-start_time)))
